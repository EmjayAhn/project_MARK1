# %% [markdown]
# # Scrapy

# %%
import scrapy
import requests
from scrapy.http import TextResponse

# %%
req = requests.get("http://markinfo.co.kr/front/phtml/c1200_r.php?p=1&trademark_name=&classsification=&asign_product=&application_number=&register_number=&publication_number=&international_register_number=&application_date=&register_date=&publication_date=&priority_date=&international_register_date=&applicant_name=&agent_name=&vienna_cd=&reg_privilege_name=&similarity_code=G4503%2BN25004%2BN25005%2BN25006%2BN25007&application_date1=&application_date2=&abandonment=true&application=true&cancel=true&expiration=true&publication=true&refused=true&registration=true&withdrawal=true&trademark=true&service_mark=true&business_emblem=true&collective_mark=true&geo_org_mark=true&trademark_service_mark=true&cert_mark=true&geo_cert_mark=true&international_mark=true&character=true&figure=true&composition_character=true&figure_composition=true&fragrance=true&sound=true&color=true&color_mixed=true&dimension=true&hologram=true&invisible=true&motion=true&visual=true&act=search&expiration_all=&mark_upclass_cd=1&mark_subclass_cd=1&sort_spec=AD&desc_sort=true")
req
# Out:
# <Response [200]>

# %%
response = TextResponse(req.url, body=req.text, encoding='utf-8')

# %%
trademarks = response.xpath('//*[@id="container"]/ul')
trademarks
# Out:
# [<Selector xpath='//*[@id="container"]/ul' data='<ul class="mark-list02">\n\t\t\t\t\t\t<li>\n\t\t\t\t'>,
#  <Selector xpath='//*[@id="container"]/ul' data='<ul class="mark-list02">\n\t\t\t\t\t\t<li>\n\t\t\t\t'>,
#  <Selector xpath='//*[@id="container"]/ul' data='<ul class="mark-list02">\n\t\t\t\t\t\t<li>\n\t\t\t\t'>,
#  <Selector xpath='//*[@id="container"]/ul' data='<ul class="mark-list02">\n\t\t\t\t\t\t<li>\n\t\t\t\t'>,
#  <Selector xpath='//*[@id="container"]/ul' data='<ul class="mark-list02">\n\t\t\t\t\t\t<li>\n\t\t\t\t'>,
#  <Selector xpath='//*[@id="container"]/ul' data='<ul class="mark-list02">\n\t\t\t\t\t\t<li>\n\t\t\t\t'>,
#  <Selector xpath='//*[@id="container"]/ul' data='<ul class="mark-list02">\n\t\t\t\t\t\t<li>\n\t\t\t\t'>]

# %%
items_row = trademarks[0].xpath('./li')
items_row[0].xpath('./a/span/img/@src').extract()[0]
# Out:
# 'http://plus.kipris.or.kr/kiprisplusws/fileToss.jsp?arg=ad7a17eeeef6e4ea4b5e22ef00dd3e293e70a322c3ead7b6f7fd85524e230d40d03b2c74864bf7f701460cca48256dddce21ef5438fee9b0'

# %%
http://plus.kipris.or.kr/kiprisplusws/fileToss.jsp?arg=ad7a17eeeef6e4ea4b5e22ef00dd3e293e70a322c3ead7b65a5015f792087f432835480dd348261ac3eb7a76fcc66d0057ddeefb8cda0a0a

# %%
count = 0
for trademark in trademarks:
    items_row = trademark.xpath('./li')
    for item in items_row:
        date = item.xpath('./a/p[1]/text()')[0].extract().replace('\n','').replace('\t','')
        status = item.xpath('./a/p[1]/span/text()')[0].extract().replace('\n','').replace('\t','')
        name = item.xpath('./a/p[2]/text()')[0].extract().replace('\n','').replace('\t','')
        item_class = item.xpath('./a/p[3]/text()')[0].extract().replace('\n','').replace('\t','')
        count += 1
        print(date)
        print(status)
        print(name)
        print(item_class)
print(count)
# Out:
# 2019.01.16
# 출원
# 박종학
# 의류/신발/모자(25)
# 2019.01.16
# 출원
# 노성현
# 의류/신발/모자(25), 광고/도소매업(35)
# 2019.01.16
# 출원
# 한세드림 주식회사
# 의류/신발/모자(25)
# 2019.01.16
# 출원
# 이동현
# 가죽제품(18), 의류/신발/모자(25), 광고/도소매업(35)
# 2019.01.16
# 출원
# 주식회사 영실업
# 의류/신발/모자(25)
# 2019.01.16
# 출원
# 주식회사 알바이오홀딩스
# 의류/신발/모자(25)
# 2019.01.16
# 출원
# 권용현
# 가정용품/유리제품(21), 의류/신발/모자(25), 요식/호텔업(43)
# 2019.01.16
# 출원
# 노성현
# 의류/신발/모자(25), 광고/도소매업(35)
# 2019.01.16
# 출원
# 노성현
# 의류/신발/모자(25), 광고/도소매업(35)
# 2019.01.16
# 출원
# 정영호
# 의류/신발/모자(25)
# 2019.01.16
# 출원
# 주식회사 코타그란데
# 의류/신발/모자(25)
# 2019.01.16
# 출원
# 황조연
# 의류/신발/모자(25)
# 2019.01.16
# 출원
# 정승모
# 의류/신발/모자(25)
# 2019.01.16
# 출원
# 방성근
# 의류/신발/모자(25)
# 2019.01.16
# 출원
# 김명조
# 의류/신발/모자(25)
# 2019.01.16
# 출원
# 주식회사 이랜드월드
# 의류/신발/모자(25)
# 2019.01.16
# 출원
# 주식회사 코타그란데
# 의류/신발/모자(25)
# 2019.01.16
# 출원
# 방성근
# 의류/신발/모자(25)
# 2019.01.16
# 출원
# 주식회사 호호당
# 의류/신발/모자(25)
# 2019.01.16
# 출원
# 주식회사 서정
# 의류/신발/모자(25)
# 2019.01.16
# 출원
# 김준환
# 의류/신발/모자(25)
# 2019.01.16
# 출원
# (주)하우스젠
# 의류/신발/모자(25)
# 2019.01.16
# 출원
# 양 위지에
# 의류/신발/모자(25)
# 2019.01.16
# 출원
# 주식회사 서정
# 의류/신발/모자(25)
# 2019.01.16
# 출원
# 오프 화이트 엘엘씨
# 화장품/세제(03), 광학/통신기기/SW(09), 가죽제품(18), 의류/신발/모자(25)
# 2019.01.16
# 출원
# 노성현
# 의류/신발/모자(25), 광고/도소매업(35)
# 2019.01.16
# 출원
# 유상곤
# 의료기기(10), 의류/신발/모자(25)
# 2019.01.16
# 출원
# 권용현
# 가정용품/유리제품(21), 의류/신발/모자(25), 요식/호텔업(43)
# 2019.01.16
# 출원
# 권용현
# 가정용품/유리제품(21), 의류/신발/모자(25), 요식/호텔업(43)
# 2019.01.16
# 출원
# 주식회사 호호당
# 의류/신발/모자(25)
# 2019.01.16
# 출원
# 주식회사 영실업
# 의류/신발/모자(25)
# 2019.01.16
# 출원
# (주)에스에프이노베이션
# 의류/신발/모자(25)
# 2019.01.16
# 출원
# 주식회사 파워풀엑스
# 화장품/세제(03), 의약품류/위생제품(05), 의료기기(10), 종이/인쇄물(16), 의류/신..
# 2019.01.15
# 출원
# 노상식
# 가죽제품(18), 의류/신발/모자(25), 광고/도소매업(35)
# 2019.01.15
# 출원
# 박순오
# 의류/신발/모자(25)
# 2019.01.15
# 출원
# 노상식
# 가죽제품(18), 의류/신발/모자(25), 광고/도소매업(35)
# 2019.01.15
# 출원
# 주식회사 바인
# 의류/신발/모자(25)
# 2019.01.15
# 출원
# 박종회
# 의류/신발/모자(25)
# 2019.01.15
# 출원
# 신동준
# 의류/신발/모자(25)
# 2019.01.15
# 출원
# 이정석
# 의류/신발/모자(25)
# 2019.01.15
# 출원
# 이선호
# 의류/신발/모자(25)
# 2019.01.15
# 출원
# 조세윤
# 의류/신발/모자(25)
# 2019.01.15
# 출원
# 주식회사 트라이본즈
# 의류/신발/모자(25)
# 2019.01.15
# 출원
# 구교민
# 의류/신발/모자(25), 광고/도소매업(35)
# 2019.01.15
# 출원
# 전국
# 의류/신발/모자(25)
# 2019.01.15
# 출원
# 박민선
# 의류/신발/모자(25)
# 2019.01.15
# 출원
# 이창준
# 의류/신발/모자(25)
# 2019.01.15
# 출원
# 오효선
# 의류/신발/모자(25), 광고/도소매업(35)
# 2019.01.15
# 출원
# 오승철
# 의류/신발/모자(25)
# 49

# %%
257247/49
# Out:
# 5249.938775510204

# %%
# !tree .
# Out:
# .
# ├── ProjectMARK1_plan.pdf
# ├── Project_MARK1.ipynb
# ├── crawling
# │   └── crawler
# │       ├── crawler
# │       │   ├── __init__.py
# │       │   ├── __pycache__
# │       │   │   ├── __init__.cpython-37.pyc
# │       │   │   ├── items.cpython-37.pyc
# │       │   │   └── settings.cpython-37.pyc
# │       │   ├── items.py
# │       │   ├── middlewares.py
# │       │   ├── pipelines.py
# │       │   ├── settings.py
# │       │   └── spiders
# │       │       ├── __init__.py
# │       │       ├── __pycache__
# │       │       │   ├── __init__.cpython-37.pyc
# │       │       │   └── spider.cpython-37.pyc
# │       │       └── spider.py
# │       ├── scrapy.cfg
# │       └── test.csv
# └── crawling_trademarks.ipynb
#
# 6 directories, 17 files

# %%
df = pd.read_csv('./crawling/crawler/test.csv')
df
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# <ipython-input-93-3ceb90bd27b6> in <module>
# ----> 1 df = pd.read_csv('./crawling/crawler/test.csv')
#       2 df
#
# ~/.pyenv/versions/3.7.0/envs/dss/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# ~/.pyenv/versions/3.7.0/envs/dss/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# ~/.pyenv/versions/3.7.0/envs/dss/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# ~/.pyenv/versions/3.7.0/envs/dss/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1012     def _make_engine(self, engine='c'):
#    1013         if engine == 'c':
# -> 1014             self._engine = CParserWrapper(self.f, **self.options)
#    1015         else:
#    1016             if engine == 'python':
#
# ~/.pyenv/versions/3.7.0/envs/dss/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1706         kwds['usecols'] = self.usecols
#    1707
# -> 1708         self._reader = parsers.TextReader(src, **kwds)
#    1709
#    1710         passed_names = self.names is None
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# EmptyDataError: No columns to parse from file

# %%
f = open('./test.txt', mode='wt', encoding='utf-8')
f.write("minjae minjae")
f.close()

# %%
f = open('./test.txt', mode='wt', encoding='utf-8')
f.write("lksjdflkajlkd")
f.close()

# %%
# !tree .
# Out:
# .
# ├── ProjectMARK1_plan.pdf
# ├── Project_MARK1.ipynb
# ├── crawling
# │   └── crawler
# │       ├── crawler
# │       │   ├── __init__.py
# │       │   ├── __pycache__
# │       │   │   ├── __init__.cpython-37.pyc
# │       │   │   ├── items.cpython-37.pyc
# │       │   │   └── settings.cpython-37.pyc
# │       │   ├── items.py
# │       │   ├── middlewares.py
# │       │   ├── pipelines.py
# │       │   ├── settings.py
# │       │   └── spiders
# │       │       ├── __init__.py
# │       │       ├── __pycache__
# │       │       │   ├── __init__.cpython-37.pyc
# │       │       │   └── spider.cpython-37.pyc
# │       │       └── spider.py
# │       ├── fashion_shirts.csv
# │       └── scrapy.cfg
# ├── crawling_trademarks.ipynb
# └── test.txt
#
# 6 directories, 18 files

# %%
df = pd.read_csv('crawling/crawler/fashion_shirts.csv', error_bad_lines=False)
# Out:
# b'Skipping line 4: expected 5 fields, saw 6\nSkipping line 7: expected 5 fields, saw 6\nSkipping line 25: expected 5 fields, saw 7\nSkipping line 28: expected 5 fields, saw 6\nSkipping line 29: expected 5 fields, saw 6\nSkipping line 33: expected 5 fields, saw 8\nSkipping line 34: expected 5 fields, saw 6\nSkipping line 36: expected 5 fields, saw 6\nSkipping line 70: expected 5 fields, saw 8\nSkipping line 71: expected 5 fields, saw 6\nSkipping line 88: expected 5 fields, saw 6\nSkipping line 89: expected 5 fields, saw 6\nSkipping line 92: expected 5 fields, saw 8\nSkipping line 96: expected 5 fields, saw 7\nSkipping line 113: expected 5 fields, saw 6\nSkipping line 121: expected 5 fields, saw 7\nSkipping line 128: expected 5 fields, saw 7\nSkipping line 130: expected 5 fields, saw 7\nSkipping line 141: expected 5 fields, saw 6\nSkipping line 153: expected 5 fields, saw 6\nSkipping line 161: expected 5 fields, saw 6\nSkipping line 163: expected 5 fields, saw 8\nSkipping line 169: expected 5 fields, saw 6\nSkipping line 177: expected 5 fields, saw 6\nSkipping line 189: expected 5 fields, saw 6\nSkipping line 194: expected 5 fields, saw 8\nSkipping line 212: expected 5 fields, saw 6\nSkipping line 233: expected 5 fields, saw 6\nSkipping line 258: expected 5 fields, saw 6\nSkipping line 262: expected 5 fields, saw 7\nSkipping line 263: expected 5 fields, saw 8\nSkipping line 274: expected 5 fields, saw 6\nSkipping line 281: expected 5 fields, saw 7\nSkipping line 283: expected 5 fields, saw 7\nSkipping line 284: expected 5 fields, saw 7\nSkipping line 285: expected 5 fields, saw 8\nSkipping line 286: expected 5 fields, saw 6\nSkipping line 287: expected 5 fields, saw 6\nSkipping line 306: expected 5 fields, saw 8\nSkipping line 322: expected 5 fields, saw 8\nSkipping line 332: expected 5 fields, saw 8\nSkipping line 333: expected 5 fields, saw 6\nSkipping line 336: expected 5 fields, saw 7\nSkipping line 338: expected 5 fields, saw 6\nSkipping line 344: expected 5 fields, saw 8\nSkipping line 369: expected 5 fields, saw 6\nSkipping line 372: expected 5 fields, saw 7\nSkipping line 376: expected 5 fields, saw 7\nSkipping line 377: expected 5 fields, saw 7\nSkipping line 386: expected 5 fields, saw 8\nSkipping line 416: expected 5 fields, saw 7\nSkipping line 431: expected 5 fields, saw 6\nSkipping line 441: expected 5 fields, saw 7\nSkipping line 442: expected 5 fields, saw 6\nSkipping line 451: expected 5 fields, saw 6\nSkipping line 458: expected 5 fields, saw 8\nSkipping line 463: expected 5 fields, saw 8\nSkipping line 469: expected 5 fields, saw 6\nSkipping line 470: expected 5 fields, saw 6\nSkipping line 479: expected 5 fields, saw 6\nSkipping line 483: expected 5 fields, saw 6\nSkipping line 484: expected 5 fields, saw 6\nSkipping line 487: expected 5 fields, saw 6\nSkipping line 511: expected 5 fields, saw 6\nSkipping line 520: expected 5 fields, saw 7\nSkipping line 532: expected 5 fields, saw 6\nSkipping line 534: expected 5 fields, saw 6\nSkipping line 535: expected 5 fields, saw 6\nSkipping line 538: expected 5 fields, saw 6\nSkipping line 539: expected 5 fields, saw 6\nSkipping line 541: expected 5 fields, saw 6\nSkipping line 552: expected 5 fields, saw 8\nSkipping line 554: expected 5 fields, saw 8\nSkipping line 557: expected 5 fields, saw 8\nSkipping line 564: expected 5 fields, saw 8\nSkipping line 589: expected 5 fields, saw 8\nSkipping line 594: expected 5 fields, saw 7\nSkipping line 595: expected 5 fields, saw 7\nSkipping line 606: expected 5 fields, saw 6\nSkipping line 612: expected 5 fields, saw 8\nSkipping line 629: expected 5 fields, saw 8\nSkipping line 636: expected 5 fields, saw 6\nSkipping line 649: expected 5 fields, saw 6\nSkipping line 660: expected 5 fields, saw 8\nSkipping line 661: expected 5 fields, saw 8\nSkipping line 662: expected 5 fields, saw 8\nSkipping line 672: expected 5 fields, saw 8\nSkipping line 673: expected 5 fields, saw 6\nSkipping line 679: expected 5 fields, saw 7\nSkipping  ...

# %%
df
# Out:
#            2019.01.16            출원     의류/신발/모자(25)  Unnamed: 3
# 2019.01.16         출원  의류/신발/모자(25)      광고/도소매업(35)         NaN
# 2019.01.16         출원  의류/신발/모자(25)              NaN         NaN
# 2019.01.16         출원  의류/신발/모자(25)              NaN         NaN
# 2019.01.16         출원  의류/신발/모자(25)              NaN         NaN
# 2019.01.16         출원  의류/신발/모자(25)      광고/도소매업(35)         NaN
# 2019.01.16         출원  의류/신발/모자(25)      광고/도소매업(35)         NaN
# 2019.01.16         출원  의류/신발/모자(25)              NaN         NaN
# 2019.01.16         출원  의류/신발/모자(25)              NaN         NaN
# 2019.01.16         출원  의류/신발/모자(25)              NaN         NaN
# 2019.01.16         출원  의류/신발/모자(25)              NaN         NaN
# 2019.01.16         출원  의류/신발/모자(25)              NaN         NaN
# 2019.01.16         출원  의류/신발/모자(25)              NaN         NaN
# 2019.01.16         출원  의류/신발/모자(25)              NaN         NaN
# 2019.01.16         출원  의류/신발/모자(25)              NaN         NaN
# 2019.01.16         출원  의류/신발/모자(25)              NaN         NaN
# 2019.01.16         출원  의류/신발/모자(25)              NaN         NaN
# 2019.01.16         출원  의류/신발/모자(25)              NaN         NaN
# 2019.01.16         출원  의류/신발/모자(25)              NaN         NaN
# 2019.01.16         출원  의류/신발/모자(25)              NaN         NaN
# 2019.01.16         출원  의류/신발/모자(25)              NaN         NaN
# 2019.01.16         출원  의류/신발/모자(25)              NaN         NaN
# 2019.01.16         출원  의류/신발/모자(25)      광고/도소매업(35)         NaN
# 2019.01.16         출원      의료기기(10)     의류/신발/모자(25)         NaN
# 2019.01.16         출원  의류/신발/모자(25)              NaN         NaN
# 2019.01.16         출원  의류/신발/모자(25)              NaN         NaN
# 2019.01.16         출원  의류/신발/모자(25)              NaN         NaN
# 2019.01.15         출원  의류/신발/모자(25)              NaN         NaN
# 2019.01.15         출원  의류/신발/모자(25)              NaN         NaN
# 2019.01.15         출원  의류/신발/모자(25)              NaN         NaN
# 2019.01.15         출원  의류/신발/모자(25)              NaN         NaN
# ...               ...           ...              ...         ...
# 2018.06.18         출원  의류/신발/모자(25)      광고/도소매업(35)         NaN
# 2018.06.18         등록  의류/신발/모자(25)              NaN         NaN
# 2018.06.18         출원  의류/신발/모자(25)     완구/스포츠용구(28)         NaN
# 2018.06.18         등록  의류/신발/모자(25)              NaN         NaN
# 2018.06.18         출원  의류/신발/모자(25)              NaN         NaN
# 2018.06.18         등록  의류/신발/모자(25)              NaN         NaN
# 2018.06.18         거절  의류/신발/모자(25)              NaN         NaN
# 2018.06.18         공고      가죽제품(18)     의류/신발/모자(25)         NaN
# 2018.06.18         출원  의류/신발/모자(25)              NaN         NaN
# 2018.06.18         출원  의류/신발/모자(25)              NaN         NaN
# 2018.06.18         거절  의류/신발/모자(25)              NaN         NaN
# 2018.06.18         거절  의류/신발/모자(25)              NaN         NaN
# 2018.06.18         출원      가죽제품(18)     의류/신발/모자(25)         NaN
# 2018.06.18         공고  의류/신발/모자(25)              NaN         NaN
# 2018.06.18         공고  의류/신발/모자(25)              NaN         NaN
#                    출원  의류/신발/모자(25)              NaN         NaN
#                    출원      가죽제품(18)     의류/신발/모자(25)         NaN
#                    출원  의류/신발/모자(25)   교육/엔터테인먼트업(41)         NaN
#                    출원  의류/신발/모자(25)              NaN         NaN
# 2018.06.15         출원  의류/신발/모자(25)              NaN         NaN
# 2018.06.15         출원  의류/신발/모자(25)              NaN         NaN
# 2018.06.15         등록  의류/신발/모자(25)              NaN         NaN
# 2018.06.15         공고  의류/신발/모자(25)              NaN         NaN
# 2018.06.15         공고  의류/신발/모자(25)              NaN         NaN
# 2018.06.15         공고  의류/신발/모자(25)              NaN         NaN
# 2018.06.15         공고  의류/신발/모자(25)              NaN         NaN
# 2018.06.15         공고  의류/신발/모자(25)              NaN         NaN
# 2018.06.15         공고  의류/신발/모자(25)      광고/도소매업(35)         NaN
# 2018.06.15         공고  의류/신발/모자(25)              NaN         NaN
# 2018.06.15         공고  의류/신발/모자(25)              NaN         NaN
#
# [4473 rows x 4 columns]

# %%
import urllib.request
urllib.request.urlretrieve("http://plus.kipris.or.kr/kiprisplusws/fileToss.jsp?arg=ad7a17eeeef6e4ea4b5e22ef00dd3e293e70a322c3ead7b615ae4bcd23950718b213b1d13acdf6048c51f226dc848202f633db9f066fa850"\
                          , "./1.jpg")
# Out:
# ('./1.jpg', <http.client.HTTPMessage at 0x103695a20>)
